# %% [markdown]
# https://plotnine.readthedocs.io/en/stable/api.html#themes
#
# https://medium.com/@gscheithauer/data-visualization-in-python-like-in-rs-ggplot2-bc62f8debbf5

# %%
import pandas as pd
import numpy as np
from plotnine import *

# %%
c_remote_data ='https://raw.githubusercontent.com/nickhould/craft-beers-dataset/master/data/processed/beers.csv'
c_col = ["#2f4858", "#f6ae2d", "#f26419",
         "#33658a", "#55dde0", "#2f4858",
         "#2f4858", "#f6ae2d", "#f26419",
         "#33658a", "#55dde0", "#2f4858"]

# useful functions
def labels(from_, to_, step_):
    return pd.Series(np.arange(from_, to_ + step_, step_)).apply(lambda x: '{:,}'.format(x)).tolist()

def breaks(from_, to_, step_):
    return pd.Series(np.arange(from_, to_ + step_, step_)).tolist()

# read data
data = pd.read_csv(c_remote_data)
data = (
    data.filter([
        'abv',
        'ibu',
        'id',
        'name',
        'style',
        'brewery_id',
        'ounces'
    ]).
    set_index('id')
)

# %%
data.head()
# Out:
#         abv  ibu                 name                           style  \
# id
# 1436  0.050  NaN             Pub Beer             American Pale Lager
# 2265  0.066  NaN          Devil's Cup         American Pale Ale (APA)
# 2264  0.071  NaN  Rise of the Phoenix                    American IPA
# 2263  0.090  NaN             Sinister  American Double / Imperial IPA
# 2262  0.075  NaN        Sex and Candy                    American IPA
#
#       brewery_id  ounces
# id
# 1436         408    12.0
# 2265         177    12.0
# 2264         177    12.0
# 2263         177    12.0
# 2262         177    12.0

# %%
data["abv"].isnull().sum()
# Out:
# 62

# %%
## Histogram

# %%
fig = (ggplot(data=data.dropna(subset=["abv"])) 
       + geom_histogram(aes(x="abv"))
      )
fig

# note : here we have used dropna in the data's abv column so that the null values can be dropped and we can instead hv a better 
# visual.
# Out:
# C:\Users\urvashi.gupta\AppData\Local\Continuum\anaconda3\lib\site-packages\plotnine\stats\stat_bin.py:93: UserWarning: 'stat_bin()' using 'bins = 50'. Pick better value with 'binwidth'.
#   warn(msg.format(params['bins']))
# <ggplot: (-9223371978852172842)>

# %%
fig = (ggplot(data=data.dropna(subset=["abv"])) 
       + geom_histogram(aes(x="abv"),fill= c_col[0],color='black',bins=100)
      )
fig

# c_col[i] gives the color changes for filling. color parameter is for border color.
# bins is for no. of bins
# Out:
# <ggplot: (-9223371978844550954)>

# %%
fig = (ggplot(data=data.dropna(subset=["abv"])) 
       + geom_histogram(aes(x="abv"),fill= c_col[0],color='black',bins=100)
       + labs(title = "Disributin of abv",x="Alcoholic content",y="Number of the users")
      )
fig
# Out:
# <ggplot: (58010221411)>

# %%
print(data["abv"].min())
print(data["abv"].max())
print(data["abv"].value_counts().min())
print(data["abv"].value_counts().max())
# Out:
# 0.001
# 0.128
# 1
# 215

# %%
data["abv"].value_counts().sort_index()
# Out:
# 0.001      1
# 0.027      2
# 0.028      1
# 0.032      3
# 0.034      1
# 0.035      6
# 0.037      4
# 0.038      6
# 0.039     15
# 0.040     38
# 0.041      9
# 0.042     38
# 0.043     12
# 0.044     16
# 0.045     89
# 0.046     32
# 0.047     57
# 0.048     72
# 0.049     59
# 0.050    215
# 0.051     62
# 0.052    107
# 0.053     60
# 0.054     50
# 0.055    158
# 0.056     66
# 0.057     52
# 0.058     66
# 0.059     34
# 0.060    125
#         ...
# 0.075     43
# 0.076      5
# 0.077     13
# 0.078     10
# 0.079      7
# 0.080     57
# 0.081      4
# 0.082     22
# 0.083      8
# 0.084      3
# 0.085     26
# 0.086      4
# 0.087     10
# 0.088      6
# 0.089      2
# 0.090     24
# 0.091      3
# 0.092     13
# 0.093      5
# 0.094      1
# 0.095      9
# 0.096      5
# 0.097      5
# 0.098      3
# 0.099     35
# 0.100      1
# 0.104      1
# 0.120      1
# 0.125      1
# 0.128      1
# Name: abv, Length: 74, dtype: int64

# %%
fig = (ggplot(data=data.dropna(subset=["abv"])) 
       + geom_histogram(aes(x="abv"),fill= c_col[0],color='black')
       + labs(title = "Disributin of abv",x="Alcoholic content",y="Number of the users")
       +
    scale_x_continuous(
        limits = (0, 0.14),
        labels = labels(0, 0.14, 0.02),
        breaks = breaks(0, 0.14, 0.02)
    ) +
    scale_y_continuous(
        limits = (0, 350),
        labels = labels(0, 350, 50),
        breaks = breaks(0, 350, 50)
    )
      )
fig
# Out:
# C:\Users\urvashi.gupta\AppData\Local\Continuum\anaconda3\lib\site-packages\plotnine\stats\stat_bin.py:93: UserWarning: 'stat_bin()' using 'bins = 50'. Pick better value with 'binwidth'.
#   warn(msg.format(params['bins']))
# C:\Users\urvashi.gupta\AppData\Local\Continuum\anaconda3\lib\site-packages\plotnine\layer.py:449: UserWarning: geom_histogram : Removed 2 rows containing missing values.
#   self.data = self.geom.handle_na(self.data)
# <ggplot: (-9223371978843374739)>

# %%
fig = (ggplot(data=data.dropna(subset=["abv"])) 
       + geom_histogram(aes(x="abv"),fill= c_col[0],color='black')
       + labs(title = "Disributin of abv",x="Alcoholic content",y="Number of the users")
       +
    scale_x_continuous(
        limits = (0, 0.14),
        labels = labels(0, 0.14, 0.02),
        breaks = breaks(0, 0.14, 0.02)
    ) +
    scale_y_continuous(
        limits = (0, 250),
        labels = labels(0, 250, 50),
        breaks = breaks(0, 250, 50)
    )
      )
fig
# Out:
# C:\Users\urvashi.gupta\AppData\Local\Continuum\anaconda3\lib\site-packages\plotnine\stats\stat_bin.py:93: UserWarning: 'stat_bin()' using 'bins = 50'. Pick better value with 'binwidth'.
#   warn(msg.format(params['bins']))
# C:\Users\urvashi.gupta\AppData\Local\Continuum\anaconda3\lib\site-packages\plotnine\layer.py:449: UserWarning: geom_histogram : Removed 4 rows containing missing values.
#   self.data = self.geom.handle_na(self.data)
# <ggplot: (58011464242)>

# %%
# changing the theme

theme_set(
    theme_538()
) # one time call

# %%
# now see the same graph again.

fig = (ggplot(data=data.dropna(subset=["abv"])) 
       + geom_histogram(aes(x="abv"),fill= c_col[0],color='black')
       + labs(title = "Disributin of abv",x="Alcoholic content",y="Number of the users")
       +
    scale_x_continuous(
        limits = (0, 0.14),
        labels = labels(0, 0.14, 0.02),
        breaks = breaks(0, 0.14, 0.02)
    ) +
    scale_y_continuous(
        limits = (0, 350),
        labels = labels(0, 350, 50),
        breaks = breaks(0, 350, 50)
    )
      )
fig
# Out:
# C:\Users\urvashi.gupta\AppData\Local\Continuum\anaconda3\lib\site-packages\plotnine\stats\stat_bin.py:93: UserWarning: 'stat_bin()' using 'bins = 50'. Pick better value with 'binwidth'.
#   warn(msg.format(params['bins']))
# C:\Users\urvashi.gupta\AppData\Local\Continuum\anaconda3\lib\site-packages\plotnine\layer.py:449: UserWarning: geom_histogram : Removed 2 rows containing missing values.
#   self.data = self.geom.handle_na(self.data)
# <ggplot: (58010242589)>

# %%
# try some other themes

theme_set(
    theme_xkcd())

# %%
fig = (ggplot(data=data.dropna(subset=["abv"])) 
       + geom_histogram(aes(x="abv"),fill= c_col[0],color='black'))
fig
# Out:
# C:\Users\urvashi.gupta\AppData\Local\Continuum\anaconda3\lib\site-packages\plotnine\stats\stat_bin.py:93: UserWarning: 'stat_bin()' using 'bins = 50'. Pick better value with 'binwidth'.
#   warn(msg.format(params['bins']))
# <ggplot: (-9223371978843230902)>

# %%
theme_set(theme_void())
fig = (ggplot(data=data.dropna(subset=["abv"])) 
       + geom_histogram(aes(x="abv"),fill= c_col[0],color='black'))
fig
# Out:
# C:\Users\urvashi.gupta\AppData\Local\Continuum\anaconda3\lib\site-packages\plotnine\stats\stat_bin.py:93: UserWarning: 'stat_bin()' using 'bins = 50'. Pick better value with 'binwidth'.
#   warn(msg.format(params['bins']))
# <ggplot: (58010295991)>

# %%
theme_set(theme_linedraw())
fig = (ggplot(data=data.dropna(subset=["abv"])) 
       + geom_histogram(aes(x="abv"),fill= c_col[0],color='black'))
fig
# Out:
# C:\Users\urvashi.gupta\AppData\Local\Continuum\anaconda3\lib\site-packages\plotnine\stats\stat_bin.py:93: UserWarning: 'stat_bin()' using 'bins = 50'. Pick better value with 'binwidth'.
#   warn(msg.format(params['bins']))
# <ggplot: (-9223371978843301586)>

# %%
theme_set(theme_classic)
fig = (ggplot(data=data.dropna(subset=["abv"])) 
       + geom_histogram(aes(x="abv"),fill= c_col[0],color='black'))
fig
# Out:
# C:\Users\urvashi.gupta\AppData\Local\Continuum\anaconda3\lib\site-packages\plotnine\stats\stat_bin.py:93: UserWarning: 'stat_bin()' using 'bins = 50'. Pick better value with 'binwidth'.
#   warn(msg.format(params['bins']))
# <ggplot: (-9223371978852196306)>

# %% [markdown]
# #### Default theme or theme_538 are good

# %%
theme_get()

# %%
# Make some axis and theme changes to theme

theme_set(theme_538()+
    theme(
        figure_size = (6, 4),
        text = element_text(
            size = 8,
            color = 'black',
            family = 'Arial'
        ),
        plot_title = element_text(
            color = 'black',
            family = 'Arial',
            weight = 'bold',
            size = 12
        ),
        axis_title = element_text(
            color = 'black',
            family = 'Arial',
            weight = 'bold',
            size = 6
        ),
    )
)

# %%
fig = (ggplot(data=data.dropna(subset=["abv"])) 
       + geom_histogram(aes(x="abv"),fill= c_col[0],color='black')
       + labs(title = "Disributin of abv",x='abv - The alcoholic content by volume (median = dashed line; mean = solid line)'
              ,y="Number of the users")
       +
    scale_x_continuous(
        limits = (0, 0.14),
        labels = labels(0, 0.14, 0.02),
        breaks = breaks(0, 0.14, 0.02)
    ) +
    scale_y_continuous(
        limits = (0, 350),
        labels = labels(0, 350, 50),
        breaks = breaks(0, 350, 50)
    )
        +
    geom_vline(aes(xintercept = data.abv.mean()), color = 'gray') +
    geom_vline(aes(xintercept = data.abv.median()), linetype = 'dashed', color = 'gray')
      )
fig
# Out:
# C:\Users\urvashi.gupta\AppData\Local\Continuum\anaconda3\lib\site-packages\plotnine\layer.py:517: MatplotlibDeprecationWarning: isinstance(..., numbers.Number)
#   return not cbook.iterable(value) and (cbook.is_numlike(value) or
# C:\Users\urvashi.gupta\AppData\Local\Continuum\anaconda3\lib\site-packages\plotnine\layer.py:517: MatplotlibDeprecationWarning: isinstance(..., numbers.Number)
#   return not cbook.iterable(value) and (cbook.is_numlike(value) or
# C:\Users\urvashi.gupta\AppData\Local\Continuum\anaconda3\lib\site-packages\plotnine\stats\stat_bin.py:93: UserWarning: 'stat_bin()' using 'bins = 50'. Pick better value with 'binwidth'.
#   warn(msg.format(params['bins']))
# C:\Users\urvashi.gupta\AppData\Local\Continuum\anaconda3\lib\site-packages\plotnine\layer.py:449: UserWarning: geom_histogram : Removed 2 rows containing missing values.
#   self.data = self.geom.handle_na(self.data)
# <ggplot: (58013031565)>

# %%
# use filter warnings to filter the warnings

import warnings
warnings.filterwarnings(action="ignore")

# %%
data["style"].unique()
# Out:
# array(['American Pale Lager', 'American Pale Ale (APA)', 'American IPA',
#        'American Double / Imperial IPA', 'Oatmeal Stout',
#        'American Porter', 'Saison / Farmhouse Ale', 'Belgian IPA',
#        'Cider', 'Baltic Porter', 'Tripel', 'American Barleywine',
#        'Winter Warmer', 'American Stout', 'Fruit / Vegetable Beer',
#        'English Strong Ale', 'American Black Ale', 'Belgian Dark Ale',
#        'American Blonde Ale', 'American Amber / Red Ale',
#        'Berliner Weissbier', 'American Brown Ale',
#        'American Pale Wheat Ale', 'Belgian Strong Dark Ale', 'Kölsch',
#        'English Pale Ale', 'American Amber / Red Lager',
#        'English Barleywine', 'Milk / Sweet Stout', 'German Pilsener',
#        'Pumpkin Ale', 'Belgian Pale Ale', 'American Pilsner',
#        'American Wild Ale', 'English Brown Ale', 'Altbier',
#        'California Common / Steam Beer', 'Gose', 'Cream Ale',
#        'Vienna Lager', 'Witbier', 'American Double / Imperial Stout',
# ...

# %%
fig = (
    ggplot(data.dropna(subset = ['abv', 'style'])[data['style'].dropna().str.contains('American')]) +
    geom_histogram(
        aes(x = 'abv'),
        fill = c_col[0], color = 'black'
    ) +
    labs(
        title ='Distribution of The alcoholic content by volume (abv)',
        x = 'abv - The alcoholic content by volume',
        y = 'Count',
    ) +
    scale_x_continuous(
        limits = (0, 0.14),
        labels = labels(0, 0.14, 0.07),
        breaks = breaks(0, 0.14, 0.07)
    ) +
    scale_y_continuous(
        limits = (0, 300),
        labels = labels(0, 300, 100),
        breaks = breaks(0, 300, 100)
    ) +
    theme(figure_size = (8, 12)) +
    facet_wrap('~style', ncol = 4)
)
fig
# Out:
# <ggplot: (58012940566)>

# %%
"d k e o f j e f".split()"d k e o f j e f".split()
# Out:
# ['d', 'k', 'e', 'o', 'f', 'j', 'e', 'f']

# %%
# barplot

(
    ggplot(data.dropna(subset = ['abv', 'style'])[data['style'].dropna().str.contains('American')]) +
    geom_bar(
        aes(x = 'style'),
        fill = c_col[0], color = 'black')
)
# Out:
# <ggplot: (-9223371978840690302)>

# %%
import seaborn as sns

# %%
data["style"].dropna().value_counts().bar()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-159-30f22e0ae0e7> in <module>()
# ----> 1 data["style"].dropna().value_counts().bar()
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    4374             if self._info_axis._can_hold_identifiers_and_holds_name(name):
#    4375                 return self[name]
# -> 4376             return object.__getattribute__(self, name)
#    4377
#    4378     def __setattr__(self, name, value):
#
# AttributeError: 'Series' object has no attribute 'bar'
